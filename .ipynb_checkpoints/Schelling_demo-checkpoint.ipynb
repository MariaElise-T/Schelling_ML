# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from random import uniform, seed
from math import sqrt
from dataclasses import dataclass

# %%
@dataclass
class Agent:
    AgentID: int
    Color: str 
    Happy: int 
    x_loc: float
    y_loc: float
    neighbors: []

# %%
def findNeighborDistances(Agent_Array):
    for i in range(0, len(Agent_Array)):
        Agent_Array[i].neighbors.clear()
        for j in range(0, len(Agent_Array)):
            Agent_Array[i].neighbors.append((Agent_Array[j].AgentID, sqrt((Agent_Array[i].x_loc-Agent_Array[j].x_loc)**2+(Agent_Array[i].y_loc-Agent_Array[j].y_loc)**2)))

# %%
def assignHappiness(Agent_Array, bias, k):
    for i in range(0, len(Agent_Array)):
        closestNeighbors = sorted(Agent_Array[i].neighbors, key = lambda x: x[1])[1:(k+1)]
        matchedNeighbors = 0
        AgentColor = Agent_Array[i].Color
        for j in range(0, len(closestNeighbors)):
            neighborID = closestNeighbors[j][0]
            for Agent in Agent_Array:
                if Agent.AgentID == neighborID:
                    if Agent.Color==AgentColor:
                        matchedNeighbors = matchedNeighbors + 1
        if(matchedNeighbors/k >= bias):
            Agent_Array[i].Happy = 1
        else:
            Agent_Array[i].Happy = 0

# %%
def decideWhoMoves(Agent_Array):
    N = len(Agent_Array)
    for i in range(0, N):
        if(Agent_Array[i].Happy == 0):
            Agent_Array[i].x_loc=uniform(0, 1)
            Agent_Array[i].y_loc=uniform(0, 1)

# %%
def plotNeighborhood(Agent_Array):
    df = pd.DataFrame( columns=['x_loc', 'y_loc', 'color'])
    i=0
    for Agent in Agent_Array:
        df.loc[i] = [Agent.x_loc, Agent.y_loc, Agent.Color]
        i = i+1
    plt.scatter(df["x_loc"], df["y_loc"], c = df["color"])
    plt.show()

# %%
def checkHappiness(Agent_Array, plots):
    NumHappy = 0
    for Agent in Agent_Array:
        if Agent.Happy == 1:
            NumHappy = NumHappy+1
    if(plots == True):
        print("Percent of happy agents: ", 100*NumHappy/len(Agent_Array), "% \n")
    return 100*NumHappy/len(Agent_Array)

# %%
def runSim(Agent_Array, steps, bias, k, plots):
    if(plots == True):
        print("Iteration 0: \n")
        plotNeighborhood(Agent_Array)
    percHappyVec = []
    for i in range(0, steps):
        findNeighborDistances(Agent_Array)
        assignHappiness(Agent_Array, bias, k)
        decideWhoMoves(Agent_Array)
        if(plots == True):
            print("Iteration ", i+1, " : \n")
        percHappy = checkHappiness(Agent_Array, plots)
        percHappyVec.append(percHappy)
        if(plots == True):
            plotNeighborhood(Agent_Array)
    return percHappyVec

# %%
def setupAndRunSim(steps, bias, k, orangeNum, greenNum, plots):
    Agent_Array = []
    for i in range(0, orangeNum):
        Agent_Array.append(Agent(AgentID=i, Color="orange", Happy=0, x_loc=uniform(0, 1), y_loc=uniform(0, 1), neighbors=[]))
    for i in range(0, greenNum):
        Agent_Array.append(Agent(AgentID=i+250, Color="green", Happy=0, x_loc=uniform(0, 1), y_loc=uniform(0, 1), neighbors=[]))
    finalPercHappyVec = runSim(Agent_Array, steps, bias, k, plots)
    return finalPercHappyVec

# %%
vec = setupAndRunSim(10, 0.51, 10, 249, 249, True)
# Out:
# Iteration 0:
# Iteration  1  :
#
# Percent of happy agents:  31.526104417670684 %
# Iteration  2  :
#
# Percent of happy agents:  46.98795180722892 %
# Iteration  3  :
#
# Percent of happy agents:  63.855421686746986 %
# Iteration  4  :
#
# Percent of happy agents:  73.09236947791165 %
# Iteration  5  :
#
# Percent of happy agents:  82.73092369477912 %
# Iteration  6  :
#
# Percent of happy agents:  89.75903614457832 %
# Iteration  7  :
#
# Percent of happy agents:  94.77911646586345 %
# Iteration  8  :
#
# Percent of happy agents:  97.18875502008032 %
# Iteration  9  :
#
# Percent of happy agents:  98.19277108433735 %
# Iteration  10  :
#
# Percent of happy agents:  98.79518072289157 %

# %%
def rejectABC_Posterior(samples, test_vec, steps, k, orangeNum, greenNum):
    params = []
    dists = []
    for i in range(0, samples):
        print("On simulation ", i+1, " of ", samples, "\n")
        gen_param = uniform(0, 1)
        gen_vec = setupAndRunSim(steps, gen_param, k, orangeNum, greenNum, False)
        dist = np.linalg.norm(np.array(test_vec)-np.array(gen_vec))
        params.append(gen_param)
        dists.append(dist)
    return params, dists

# %%
params, dists = rejectABC_Posterior(1000, vec, 10, 10, 249, 249)
# Out:
# On simulation  1  of  1000
#
# On simulation  2  of  1000
#
# On simulation  3  of  1000
#
# On simulation  4  of  1000
#
# On simulation  5  of  1000
#
# On simulation  6  of  1000
#
# On simulation  7  of  1000
#
# On simulation  8  of  1000
#
# On simulation  9  of  1000
#
# On simulation  10  of  1000
#
# On simulation  11  of  1000
#
# On simulation  12  of  1000
#
# On simulation  13  of  1000
#
# On simulation  14  of  1000
#
# On simulation  15  of  1000
#
# On simulation  16  of  1000
#
# On simulation  17  of  1000
#
# On simulation  18  of  1000
#
# On simulation  19  of  1000
#
# On simulation  20  of  1000
#
# On simulation  21  of  1000
#
# On simulation  22  of  1000
#
# On simulation  23  of  1000
#
# On simulation  24  of  1000
#
# On simulation  25  of  1000
#
# On simulation  26  of  1000
#
# On simulation  27  of  1000
#
# On simulation  28  of  1000
#
# On simulation  29  of  1000
#
# On simulation  30  of  1000
#
# On simulation  31  of  1000
#
# On simulation  32  of  1000
#
# On simulation  33  of  1000
#
# On simulation  34  of  1000
#
# On simulation  35  of  1000
#
# On simulation  36  of  1000
#
# On simulation  37  of  1000
#
# On simulation  38  of  1000
#
# On simulation  39  of  1000
#
# On simulation  40  of  1000
#
# On simulation  41  of  1000
#
# On simulation  42  of  1000
#
# On simulation  43  of  1000
#
# On simulation  44  of  1000
#
# On simulation  45  of  1000
#
# On simulation  46  of  1000
#
# On simulation  47  of  1000
#
# On simulation  48  of  1000
#
# On simulation  49  of  1000
#
# On simulation  50  of  1000
#
# On simulation  51  of  1000
#
# On simulation  52  of  1000
#
# On simulation  53  of  1000
#
# On simulation  54  of  1000
#
# On simulation  55  of  1000
#
# On simulation  56  of  1000
#
# On simulation  57  of  1000
#
# On simulation  58  of  1000
#
# On simulation  59  of  1000
#
# On simulation  60  of  1000
#
# On simulation  61  of  1000
#
# On simulation  62  of  1000
#
# On simulation  63  of  1000
#
# On simulation  64  of  1000
#
# On simulation  65  of  1000
#
# On simulation  66  of  1000
#
# On simulation  67  of  1000
#
# On simulation  68  of  1000
#
# On simulation  69  of  1000
#
# On simulation  70  of  1000
#
# On simulation  71  of  1000
#
# On simulation  72  of  1000
#
# On simulation  73  of  1000
#
# On simulation  74  of  1000
#
# On simulation  75  of  1000
#
# On simulation  76  of  1000
#
# On simulation  77  of  1000
#
# On simulation  78  of  1000
#
# On simulation  79  of  1000
#
# On simulation  80  of  1000
#
# On simulation  81  of  1000
#
# On simulation  82  of  1000
#
# On simulation  83  of  1000
#
# On simulation  84  of  1000
#
# On simulation  85  of  1000
#
# On simulation  86  of  1000
#
# On simulation  87  of  1000
#
# On simulation  88  of  1000
#
# On simulation  89  of  1000
#
# On simulation  90  of  1000
#
# On simulation  91  of  1000
#
# On simulation  92  of  1000
#
# On simulation  93  of  1000
#
# On simulation  94  of  1000
#
# On simulation  95  of  1000
#
# On simulation  96  of  1000
#
# On simulation  97  of  1000
#
# On simulation  98  of  1000
#
# On simulation  99  of  1000
#
# On simulation  100  of  1000
#
# On simulation  101  of  1000
#
# On simulation  102  of  1000
#
# On simulation  103  of  1000
#
# On simulation  104  of  1000
#
# On simulation  105  of  1000
#
# On simulation  106  of  1000
#
# On simulation  107  of  1000
#
# On simulation  108  of  1000
#
# On simulation  109  of  1000
#
# On simulation  110  of  1000
#
# On simulation  111  of  1000
#
# On simulation  112  of  1000
#
# On simulation  113  of  1000
#
# On simulation  114  of  1000
#
# On simulation  115  of  1000
#
# On simulation  116  of  1000
#
# On simulation  117  of  1000
#
# On simulation  118  of  1000
#
# On simulation  119  of  1000
#
# On simulation  120  of  1000
#
# On simulation  121  of  1000
#
# On simulation  122  of  1000
#
# On simulation  123  of  1000
#
# On simulation  124  of  1000
#
# On simulation  125  of  1000
#
# On simulation  126  of  1000
#
# On simulation  127  of  1000
#
# On simulation  128  of  1000
#
# On simulation  129  of  1000
#
# On simulation  130  of  1000
#
# On simulation  131  of  1000
#
# On simulation  132  of  1000
#
# On simulation  133  of  1000
#
# On simulation  134  of  1000
#
# On simulation  135  of  1000
#
# On simulation  136  of  1000
#
# On simulation  137  of  1000
#
# On simulation  138  of  1000
#
# On simulation  139  of  1000
#
# On simulation  140  of  1000
#
# On simulation  141  of  1000
#
# On simulation  142  of  1000
#
# On simulation  143  of  1000
#
# On simulation  144  of  1000
#
# On simulation  145  of  1000
#
# On simulation  146  of  1000
#
# On simulation  147  of  1000
#
# On simulation  148  of  1000
#
# On simulation  149  of  1000
#
# On simulation  150  of  1000
#
# On simulation  151  of  1000
#
# On simulation  152  of  1000
#
# On simulation  153  of  1000
#
# On simulation  154  of  1000
#
# On simulation  155  of  1000
#
# On simulation  156  of  1000
#
# On simulation  157  of  1000
#
# On simulation  158  of  1000
#
# On simulation  159  of  1000
#
# On simulation  160  of  1000
#
# On simulation  161  of  1000
#
# On simulation  162  of  1000
#
# On simulation  163  of  1000
#
# On simulation  164  of  1000
#
# On simulation  165  of  1000
#
# On simulation  166  of  1000
#
# On simulation  167  of  1000
#
# On simulation  168  of  1000
#
# On simulation  169  of  1000
#
# On simulation  170  of  1000
#
# On simulation  171  of  1000
#
# On simulation  172  of  1000
#
# On simulation  173  of  1000
#
# On simulation  174  of  1000
#
# On simulation  175  of  1000
#
# On simulation  176  of  1000
#
# On simulation  177  of  1000
#
# On simulation  178  of  1000
#
# On simulation  179  of  1000
#
# On simulation  180  of  1000
#
# On simulation  181  of  1000
#
# On simulation  182  of  1000
#
# On simulation  183  of  1000
#
# On simulation  184  of  1000
#
# On simulation  185  of  1000
#
# On simulation  186  of  1000
#
# On simulation  187  of  1000
#
# On simulation  188  of  1000
#
# On simulation  189  of  1000
#
# On simulation  190  of  1000
#
# On simulation  191  of  1000
#
# On simulation  192  of  1000
#
# On simulation  193  of  1000
#
# On simulation  194  of  1000
#
# On simulation  195  of  1000
#
# On simulation  196  of  1000
#
# On simulation  197  of  1000
#
# On simulation  198  of  1000
#
# On simulation  199  of  1000
#
# On simulation  200  of  1000
#
# On simulation  201  of  1000
#
# On simulation  202  of  1000
#
# On simulation  203  of  1000
#
# On simulation  204  of  1000
#
# On simulation  205  of  1000
#
# On simulation  206  of  1000
#
# On simulation  207  of  1000
#
# On simulation  208  of  1000
#
# On simulation  209  of  1000
#
# On simulation  210  of  1000
#
# On simulation  211  of  1000
#
# On simulation  212  of  1000
#
# On simulation  213  of  1000
#
# On simulation  214  of  1000
#
# On simulation  215  of  1000
#
# On simulation  216  of  1000
#
# On simulation  217  of  1000
#
# On simulation  218  of  1000
#
# On simulation  219  of  1000
#
# On simulation  220  of  1000
#
# On simulation  221  of  1000
#
# On simulation  222  of  1000
#
# On simulation  223  of  1000
#
# On simulation  224  of  1000
#
# On simulation  225  of  1000
#
# On simulation  226  of  1000
#
# On simulation  227  of  1000
#
# On simulation  228  of  1000
#
# On simulation  229  of  1000
#
# On simulation  230  of  1000
#
# On simulation  231  of  1000
#
# On simulation  232  of  1000
#
# On simulation  233  of  1000
#
# On simulation  234  of  1000
#
# On simulation  235  of  1000
#
# On simulation  236  of  1000
#
# On simulation  237  of  1000
#
# On simulation  238  of  1000
#
# On simulation  239  of  1000
#
# On simulation  240  of  1000
#
# On simulation  241  of  1000
#
# On simulation  242  of  1000
#
# On simulation  243  of  1000
#
# On simulation  244  of  1000
#
# On simulation  245  of  1000
#
# On simulation  246  of  1000
#
# On simulation  247  of  1000
#
# On simulation  248  of  1000
#
# On simulation  249  of  1000
#
# On simulation  250  of  1000
#
# On simulation  251  of  1000
#
# On simulation  252  of  1000
#
# On simulation  253  of  1000
#
# On simulation  254  of  1000
#
# On simulation  255  of  1000
#
# On simulation  256  of  1000
#
# On simulation  257  of  1000
#
# On simulation  258  of  1000
#
# On simulation  259  of  1000
#
# On simulation  260  of  1000
#
# On simulation  261  of  1000
#
# On simulation  262  of  1000
#
# On simulation  263  of  1000
#
# On simulation  264  of  1000
#
# On simulation  265  of  1000
#
# On simulation  266  of  1000
#
# On simulation  267  of  1000
#
# On simulation  268  of  1000
# On simulation  269  of  1000
#
# On simulation  270  of  1000
#
# On simulation  271  of  1000
#
# On simulation  272  of  1000
#
# On simulation  273  of  1000
#
# On simulation  274  of  1000
#
# On simulation  275  of  1000
#
# On simulation  276  of  1000
#
# On simulation  277  of  1000
#
# On simulation  278  of  1000
#
# On simulation  279  of  1000
#
# On simulation  280  of  1000
#
# On simulation  281  of  1000
#
# On simulation  282  of  1000
#
# On simulation  283  of  1000
#
# On simulation  284  of  1000
#
# On simulation  285  of  1000
#
# On simulation  286  of  1000
#
# On simulation  287  of  1000
#
# On simulation  288  of  1000
#
# On simulation  289  of  1000
#
# On simulation  290  of  1000
#
# On simulation  291  of  1000
#
# On simulation  292  of  1000
#
# On simulation  293  of  1000
#
# On simulation  294  of  1000
#
# On simulation  295  of  1000
#
# On simulation  296  of  1000
#
# On simulation  297  of  1000
#
# On simulation  298  of  1000
#
# On simulation  299  of  1000
#
# On simulation  300  of  1000
#
# On simulation  301  of  1000
#
# On simulation  302  of  1000
#
# On simulation  303  of  1000
#
# On simulation  304  of  1000
#
# On simulation  305  of  1000
#
# On simulation  306  of  1000
#
# On simulation  307  of  1000
#
# On simulation  308  of  1000
#
# On simulation  309  of  1000
#
# On simulation  310  of  1000
#
# On simulation  311  of  1000
#
# On simulation  312  of  1000
#
# On simulation  313  of  1000
#
# On simulation  314  of  1000
#
# On simulation  315  of  1000
#
# On simulation  316  of  1000
#
# On simulation  317  of  1000
#
# On simulation  318  of  1000
#
# On simulation  319  of  1000
#
# On simulation  320  of  1000
#
# On simulation  321  of  1000
#
# On simulation  322  of  1000
#
# On simulation  323  of  1000
#
# On simulation  324  of  1000
#
# On simulation  325  of  1000
#
# On simulation  326  of  1000
#
# On simulation  327  of  1000
#
# On simulation  328  of  1000
#
# On simulation  329  of  1000
#
# On simulation  330  of  1000
#
# On simulation  331  of  1000
#
# On simulation  332  of  1000
#
# On simulation  333  of  1000
#
# On simulation  334  of  1000
#
# On simulation  335  of  1000
#
# On simulation  336  of  1000
#
# On simulation  337  of  1000
#
# On simulation  338  of  1000
#
# On simulation  339  of  1000
#
# On simulation  340  of  1000
#
# On simulation  341  of  1000
#
# On simulation  342  of  1000
#
# On simulation  343  of  1000
#
# On simulation  344  of  1000
#
# On simulation  345  of  1000
#
# On simulation  346  of  1000
#
# On simulation  347  of  1000
#
# On simulation  348  of  1000
#
# On simulation  349  of  1000
#
# On simulation  350  of  1000
#
# On simulation  351  of  1000
#
# On simulation  352  of  1000
#
# On simulation  353  of  1000
#
# On simulation  354  of  1000
#
# On simulation  355  of  1000
#
# On simulation  356  of  1000
#
# On simulation  357  of  1000
#
# On simulation  358  of  1000
#
# On simulation  359  of  1000
#
# On simulation  360  of  1000
#
# On simulation  361  of  1000
#
# On simulation  362  of  1000
#
# On simulation  363  of  1000
#
# On simulation  364  of  1000
#
# On simulation  365  of  1000
#
# On simulation  366  of  1000
#
# On simulation  367  of  1000
#
# On simulation  368  of  1000
#
# On simulation  369  of  1000
#
# On simulation  370  of  1000
#
# On simulation  371  of  1000
#
# On simulation  372  of  1000
#
# On simulation  373  of  1000
#
# On simulation  374  of  1000
#
# On simulation  375  of  1000
#
# On simulation  376  of  1000
#
# On simulation  377  of  1000
#
# On simulation  378  of  1000
#
# On simulation  379  of  1000
#
# On simulation  380  of  1000
#
# On simulation  381  of  1000
#
# On simulation  382  of  1000
#
# On simulation  383  of  1000
#
# On simulation  384  of  1000
#
# On simulation  385  of  1000
#
# On simulation  386  of  1000
#
# On simulation  387  of  1000
#
# On simulation  388  of  1000
#
# On simulation  389  of  1000
#
# On simulation  390  of  1000
#
# On simulation  391  of  1000
#
# On simulation  392  of  1000
#
# On simulation  393  of  1000
#
# On simulation  394  of  1000
#
# On simulation  395  of  1000
#
# On simulation  396  of  1000
#
# On simulation  397  of  1000
#
# On simulation  398  of  1000
#
# On simulation  399  of  1000
#
# On simulation  400  of  1000
#
# On simulation  401  of  1000
#
# On simulation  402  of  1000
#
# On simulation  403  of  1000
#
# On simulation  404  of  1000
#
# On simulation  405  of  1000
#
# On simulation  406  of  1000
#
# On simulation  407  of  1000
#
# On simulation  408  of  1000
#
# On simulation  409  of  1000
#
# On simulation  410  of  1000
#
# On simulation  411  of  1000
#
# On simulation  412  of  1000
#
# On simulation  413  of  1000
#
# On simulation  414  of  1000
#
# On simulation  415  of  1000
#
# On simulation  416  of  1000
#
# On simulation  417  of  1000
#
# On simulation  418  of  1000
#
# On simulation  419  of  1000
#
# On simulation  420  of  1000
#
# On simulation  421  of  1000
#
# On simulation  422  of  1000
#
# On simulation  423  of  1000
#
# On simulation  424  of  1000
#
# On simulation  425  of  1000
#
# On simulation  426  of  1000
#
# On simulation  427  of  1000
#
# On simulation  428  of  1000
#
# On simulation  429  of  1000
#
# On simulation  430  of  1000
#
# On simulation  431  of  1000
#
# On simulation  432  of  1000
#
# On simulation  433  of  1000
#
# On simulation  434  of  1000
#
# On simulation  435  of  1000
#
# On simulation  436  of  1000
#
# On simulation  437  of  1000
#
# On simulation  438  of  1000
#
# On simulation  439  of  1000
#
# On simulation  440  of  1000
#
# On simulation  441  of  1000
#
# On simulation  442  of  1000
#
# On simulation  443  of  1000
#
# On simulation  444  of  1000
#
# On simulation  445  of  1000
#
# On simulation  446  of  1000
#
# On simulation  447  of  1000
#
# On simulation  448  of  1000
#
# On simulation  449  of  1000
#
# On simulation  450  of  1000
#
# On simulation  451  of  1000
#
# On simulation  452  of  1000
#
# On simulation  453  of  1000
#
# On simulation  454  of  1000
#
# On simulation  455  of  1000
#
# On simulation  456  of  1000
#
# On simulation  457  of  1000
#
# On simulation  458  of  1000
#
# On simulation  459  of  1000
#
# On simulation  460  of  1000
#
# On simulation  461  of  1000
#
# On simulation  462  of  1000
#
# On simulation  463  of  1000
#
# On simulation  464  of  1000
#
# On simulation  465  of  1000
#
# On simulation  466  of  1000
#
# On simulation  467  of  1000
#
# On simulation  468  of  1000
#
# On simulation  469  of  1000
#
# On simulation  470  of  1000
#
# On simulation  471  of  1000
#
# On simulation  472  of  1000
#
# On simulation  473  of  1000
#
# On simulation  474  of  1000
#
# On simulation  475  of  1000
#
# On simulation  476  of  1000
#
# On simulation  477  of  1000
#
# On simulation  478  of  1000
#
# On simulation  479  of  1000
#
# On simulation  480  of  1000
#
# On simulation  481  of  1000
#
# On simulation  482  of  1000
#
# On simulation  483  of  1000
#
# On simulation  484  of  1000
#
# On simulation  485  of  1000
#
# On simulation  486  of  1000
#
# On simulation  487  of  1000
#
# On simulation  488  of  1000
#
# On simulation  489  of  1000
#
# On simulation  490  of  1000
#
# On simulation  491  of  1000
#
# On simulation  492  of  1000
#
# On simulation  493  of  1000
#
# On simulation  494  of  1000
#
# On simulation  495  of  1000
#
# On simulation  496  of  1000
#
# On simulation  497  of  1000
#
# On simulation  498  of  1000
#
# On simulation  499  of  1000
#
# On simulation  500  of  1000
#
# On simulation  501  of  1000
#
# On simulation  502  of  1000
#
# On simulation  503  of  1000
#
# On simulation  504  of  1000
#
# On simulation  505  of  1000
#
# On simulation  506  of  1000
#
# On simulation  507  of  1000
#
# On simulation  508  of  1000
#
# On simulation  509  of  1000
#
# On simulation  510  of  1000
#
# On simulation  511  of  1000
#
# On simulation  512  of  1000
#
# On simulation  513  of  1000
#
# On simulation  514  of  1000
#
# On simulation  515  of  1000
#
# On simulation  516  of  1000
#
# On simulation  517  of  1000
#
# On simulation  518  of  1000
#
# On simulation  519  of  1000
#
# On simulation  520  of  1000
#
# On simulation  521  of  1000
#
# On simulation  522  of  1000
#
# On simulation  523  of  1000
#
# On simulation  524  of  1000
#
# On simulation  525  of  1000
#
# On simulation  526  of  1000
#
# On simulation  527  of  1000
#
# On simulation  528  of  1000
#
# On simulation  529  of  1000
#
# On simulation  530  of  1000
#
# On simulation  531  of  1000
#
# On simulation  532  of  1000
#
# On simulation  533  of  1000
# On simulation  534  of  1000
#
# On simulation  535  of  1000
#
# On simulation  536  of  1000
#
# On simulation  537  of  1000
#
# On simulation  538  of  1000
#
# On simulation  539  of  1000
#
# On simulation  540  of  1000
#
# On simulation  541  of  1000
#
# On simulation  542  of  1000
#
# On simulation  543  of  1000
#
# On simulation  544  of  1000
#
# On simulation  545  of  1000
#
# On simulation  546  of  1000
#
# On simulation  547  of  1000
#
# On simulation  548  of  1000
#
# On simulation  549  of  1000
#
# On simulation  550  of  1000
#
# On simulation  551  of  1000
#
# On simulation  552  of  1000
#
# On simulation  553  of  1000
#
# On simulation  554  of  1000
#
# On simulation  555  of  1000
#
# On simulation  556  of  1000
#
# On simulation  557  of  1000
#
# On simulation  558  of  1000
#
# On simulation  559  of  1000
#
# On simulation  560  of  1000
#
# On simulation  561  of  1000
#
# On simulation  562  of  1000
#
# On simulation  563  of  1000
#
# On simulation  564  of  1000
#
# On simulation  565  of  1000
#
# On simulation  566  of  1000
#
# On simulation  567  of  1000
#
# On simulation  568  of  1000
#
# On simulation  569  of  1000
#
# On simulation  570  of  1000
#
# On simulation  571  of  1000
#
# On simulation  572  of  1000
#
# On simulation  573  of  1000
#
# On simulation  574  of  1000
#
# On simulation  575  of  1000
#
# On simulation  576  of  1000
#
# On simulation  577  of  1000
#
# On simulation  578  of  1000
#
# On simulation  579  of  1000
#
# On simulation  580  of  1000
#
# On simulation  581  of  1000
#
# On simulation  582  of  1000
#
# On simulation  583  of  1000
#
# On simulation  584  of  1000
#
# On simulation  585  of  1000
#
# On simulation  586  of  1000
#
# On simulation  587  of  1000
#
# On simulation  588  of  1000
#
# On simulation  589  of  1000
#
# On simulation  590  of  1000
#
# On simulation  591  of  1000
#
# On simulation  592  of  1000
#
# On simulation  593  of  1000
#
# On simulation  594  of  1000
#
# On simulation  595  of  1000
#
# On simulation  596  of  1000
#
# On simulation  597  of  1000
#
# On simulation  598  of  1000
#
# On simulation  599  of  1000
#
# On simulation  600  of  1000
#
# On simulation  601  of  1000
#
# On simulation  602  of  1000
#
# On simulation  603  of  1000
#
# On simulation  604  of  1000
#
# On simulation  605  of  1000
#
# On simulation  606  of  1000
#
# On simulation  607  of  1000
#
# On simulation  608  of  1000
#
# On simulation  609  of  1000
#
# On simulation  610  of  1000
#
# On simulation  611  of  1000
#
# On simulation  612  of  1000
#
# On simulation  613  of  1000
#
# On simulation  614  of  1000
#
# On simulation  615  of  1000
#
# On simulation  616  of  1000
#
# On simulation  617  of  1000
#
# On simulation  618  of  1000
#
# On simulation  619  of  1000
#
# On simulation  620  of  1000
#
# On simulation  621  of  1000
#
# On simulation  622  of  1000
#
# On simulation  623  of  1000
#
# On simulation  624  of  1000
#
# On simulation  625  of  1000
#
# On simulation  626  of  1000
#
# On simulation  627  of  1000
#
# On simulation  628  of  1000
#
# On simulation  629  of  1000
#
# On simulation  630  of  1000
#
# On simulation  631  of  1000
#
# On simulation  632  of  1000
#
# On simulation  633  of  1000
#
# On simulation  634  of  1000
#
# On simulation  635  of  1000
#
# On simulation  636  of  1000
#
# On simulation  637  of  1000
#
# On simulation  638  of  1000
#
# On simulation  639  of  1000
#
# On simulation  640  of  1000
#
# On simulation  641  of  1000
#
# On simulation  642  of  1000
#
# On simulation  643  of  1000
#
# On simulation  644  of  1000
#
# On simulation  645  of  1000
#
# On simulation  646  of  1000
#
# On simulation  647  of  1000
#
# On simulation  648  of  1000
#
# On simulation  649  of  1000
#
# On simulation  650  of  1000
#
# On simulation  651  of  1000
#
# On simulation  652  of  1000
#
# On simulation  653  of  1000
#
# On simulation  654  of  1000
#
# On simulation  655  of  1000
#
# On simulation  656  of  1000
#
# On simulation  657  of  1000
#
# On simulation  658  of  1000
#
# On simulation  659  of  1000
#
# On simulation  660  of  1000
#
# On simulation  661  of  1000
#
# On simulation  662  of  1000
#
# On simulation  663  of  1000
#
# On simulation  664  of  1000
#
# On simulation  665  of  1000
#
# On simulation  666  of  1000
#
# On simulation  667  of  1000
#
# On simulation  668  of  1000
#
# On simulation  669  of  1000
#
# On simulation  670  of  1000
#
# On simulation  671  of  1000
#
# On simulation  672  of  1000
#
# On simulation  673  of  1000
#
# On simulation  674  of  1000
#
# On simulation  675  of  1000
#
# On simulation  676  of  1000
#
# On simulation  677  of  1000
#
# On simulation  678  of  1000
#
# On simulation  679  of  1000
#
# On simulation  680  of  1000
#
# On simulation  681  of  1000
#
# On simulation  682  of  1000
#
# On simulation  683  of  1000
#
# On simulation  684  of  1000
#
# On simulation  685  of  1000
#
# On simulation  686  of  1000
#
# On simulation  687  of  1000
#
# On simulation  688  of  1000
#
# On simulation  689  of  1000
#
# On simulation  690  of  1000
#
# On simulation  691  of  1000
#
# On simulation  692  of  1000
#
# On simulation  693  of  1000
#
# On simulation  694  of  1000
#
# On simulation  695  of  1000
#
# On simulation  696  of  1000
#
# On simulation  697  of  1000
#
# On simulation  698  of  1000
#
# On simulation  699  of  1000
#
# On simulation  700  of  1000
#
# On simulation  701  of  1000
#
# On simulation  702  of  1000
#
# On simulation  703  of  1000
#
# On simulation  704  of  1000
#
# On simulation  705  of  1000
#
# On simulation  706  of  1000
#
# On simulation  707  of  1000
#
# On simulation  708  of  1000
#
# On simulation  709  of  1000
#
# On simulation  710  of  1000
#
# On simulation  711  of  1000
#
# On simulation  712  of  1000
#
# On simulation  713  of  1000
#
# On simulation  714  of  1000
#
# On simulation  715  of  1000
#
# On simulation  716  of  1000
#
# On simulation  717  of  1000
#
# On simulation  718  of  1000
#
# On simulation  719  of  1000
#
# On simulation  720  of  1000
#
# On simulation  721  of  1000
#
# On simulation  722  of  1000
#
# On simulation  723  of  1000
#
# On simulation  724  of  1000
#
# On simulation  725  of  1000
#
# On simulation  726  of  1000
#
# On simulation  727  of  1000
#
# On simulation  728  of  1000
#
# On simulation  729  of  1000
#
# On simulation  730  of  1000
#
# On simulation  731  of  1000
#
# On simulation  732  of  1000
#
# On simulation  733  of  1000
#
# On simulation  734  of  1000
#
# On simulation  735  of  1000
#
# On simulation  736  of  1000
#
# On simulation  737  of  1000
#
# On simulation  738  of  1000
#
# On simulation  739  of  1000
#
# On simulation  740  of  1000
#
# On simulation  741  of  1000
#
# On simulation  742  of  1000
#
# On simulation  743  of  1000
#
# On simulation  744  of  1000
#
# On simulation  745  of  1000
#
# On simulation  746  of  1000
#
# On simulation  747  of  1000
#
# On simulation  748  of  1000
#
# On simulation  749  of  1000
#
# On simulation  750  of  1000
#
# On simulation  751  of  1000
#
# On simulation  752  of  1000
#
# On simulation  753  of  1000
#
# On simulation  754  of  1000
#
# On simulation  755  of  1000
#
# On simulation  756  of  1000
#
# On simulation  757  of  1000
#
# On simulation  758  of  1000
#
# On simulation  759  of  1000
#
# On simulation  760  of  1000
#
# On simulation  761  of  1000
#
# On simulation  762  of  1000
#
# On simulation  763  of  1000
#
# On simulation  764  of  1000
#
# On simulation  765  of  1000
#
# On simulation  766  of  1000
#
# On simulation  767  of  1000
#
# On simulation  768  of  1000
#
# On simulation  769  of  1000
#
# On simulation  770  of  1000
#
# On simulation  771  of  1000
#
# On simulation  772  of  1000
#
# On simulation  773  of  1000
#
# On simulation  774  of  1000
#
# On simulation  775  of  1000
#
# On simulation  776  of  1000
#
# On simulation  777  of  1000
#
# On simulation  778  of  1000
#
# On simulation  779  of  1000
#
# On simulation  780  of  1000
#
# On simulation  781  of  1000
#
# On simulation  782  of  1000
#
# On simulation  783  of  1000
#
# On simulation  784  of  1000
#
# On simulation  785  of  1000
#
# On simulation  786  of  1000
#
# On simulation  787  of  1000
#
# On simulation  788  of  1000
#
# On simulation  789  of  1000
#
# On simulation  790  of  1000
#
# On simulation  791  of  1000
#
# On simulation  792  of  1000
#
# On simulation  793  of  1000
#
# On simulation  794  of  1000
#
# On simulation  795  of  1000
#
# On simulation  796  of  1000
#
# On simulation  797  of  1000
#
# On simulation  798  of  1000
# On simulation  799  of  1000
#
# On simulation  800  of  1000
#
# On simulation  801  of  1000
#
# On simulation  802  of  1000
#
# On simulation  803  of  1000
#
# On simulation  804  of  1000
#
# On simulation  805  of  1000
#
# On simulation  806  of  1000
#
# On simulation  807  of  1000
#
# On simulation  808  of  1000
#
# On simulation  809  of  1000
#
# On simulation  810  of  1000
#
# On simulation  811  of  1000
#
# On simulation  812  of  1000
#
# On simulation  813  of  1000
#
# On simulation  814  of  1000
#
# On simulation  815  of  1000
#
# On simulation  816  of  1000
#
# On simulation  817  of  1000
#
# On simulation  818  of  1000
#
# On simulation  819  of  1000
#
# On simulation  820  of  1000
#
# On simulation  821  of  1000
#
# On simulation  822  of  1000
#
# On simulation  823  of  1000
#
# On simulation  824  of  1000
#
# On simulation  825  of  1000
#
# On simulation  826  of  1000
#
# On simulation  827  of  1000
#
# On simulation  828  of  1000
#
# On simulation  829  of  1000
#
# On simulation  830  of  1000
#
# On simulation  831  of  1000
#
# On simulation  832  of  1000
#
# On simulation  833  of  1000
#
# On simulation  834  of  1000
#
# On simulation  835  of  1000
#
# On simulation  836  of  1000
#
# On simulation  837  of  1000
#
# On simulation  838  of  1000
#
# On simulation  839  of  1000
#
# On simulation  840  of  1000
#
# On simulation  841  of  1000
#
# On simulation  842  of  1000
#
# On simulation  843  of  1000
#
# On simulation  844  of  1000
#
# On simulation  845  of  1000
#
# On simulation  846  of  1000
#
# On simulation  847  of  1000
#
# On simulation  848  of  1000
#
# On simulation  849  of  1000
#
# On simulation  850  of  1000
#
# On simulation  851  of  1000
#
# On simulation  852  of  1000
#
# On simulation  853  of  1000
#
# On simulation  854  of  1000
#
# On simulation  855  of  1000
#
# On simulation  856  of  1000
#
# On simulation  857  of  1000
#
# On simulation  858  of  1000
#
# On simulation  859  of  1000
#
# On simulation  860  of  1000
#
# On simulation  861  of  1000
#
# On simulation  862  of  1000
#
# On simulation  863  of  1000
#
# On simulation  864  of  1000
#
# On simulation  865  of  1000
#
# On simulation  866  of  1000
#
# On simulation  867  of  1000
#
# On simulation  868  of  1000
#
# On simulation  869  of  1000
#
# On simulation  870  of  1000
#
# On simulation  871  of  1000
#
# On simulation  872  of  1000
#
# On simulation  873  of  1000
#
# On simulation  874  of  1000
#
# On simulation  875  of  1000
#
# On simulation  876  of  1000
#
# On simulation  877  of  1000
#
# On simulation  878  of  1000
#
# On simulation  879  of  1000
#
# On simulation  880  of  1000
#
# On simulation  881  of  1000
#
# On simulation  882  of  1000
#
# On simulation  883  of  1000
#
# On simulation  884  of  1000
#
# On simulation  885  of  1000
#
# On simulation  886  of  1000
#
# On simulation  887  of  1000
#
# On simulation  888  of  1000
#
# On simulation  889  of  1000
#
# On simulation  890  of  1000
#
# On simulation  891  of  1000
#
# On simulation  892  of  1000
#
# On simulation  893  of  1000
#
# On simulation  894  of  1000
#
# On simulation  895  of  1000
#
# On simulation  896  of  1000
#
# On simulation  897  of  1000
#
# On simulation  898  of  1000
#
# On simulation  899  of  1000
#
# On simulation  900  of  1000
#
# On simulation  901  of  1000
#
# On simulation  902  of  1000
#
# On simulation  903  of  1000
#
# On simulation  904  of  1000
#
# On simulation  905  of  1000
#
# On simulation  906  of  1000
#
# On simulation  907  of  1000
#
# On simulation  908  of  1000
#
# On simulation  909  of  1000
#
# On simulation  910  of  1000
#
# On simulation  911  of  1000
#
# On simulation  912  of  1000
#
# On simulation  913  of  1000
#
# On simulation  914  of  1000
#
# On simulation  915  of  1000
#
# On simulation  916  of  1000
#
# On simulation  917  of  1000
#
# On simulation  918  of  1000
#
# On simulation  919  of  1000
#
# On simulation  920  of  1000
#
# On simulation  921  of  1000
#
# On simulation  922  of  1000
#
# On simulation  923  of  1000
#
# On simulation  924  of  1000
#
# On simulation  925  of  1000
#
# On simulation  926  of  1000
#
# On simulation  927  of  1000
#
# On simulation  928  of  1000
#
# On simulation  929  of  1000
#
# On simulation  930  of  1000
#
# On simulation  931  of  1000
#
# On simulation  932  of  1000
#
# On simulation  933  of  1000
#
# On simulation  934  of  1000
#
# On simulation  935  of  1000
#
# On simulation  936  of  1000
#
# On simulation  937  of  1000
#
# On simulation  938  of  1000
#
# On simulation  939  of  1000
#
# On simulation  940  of  1000
#
# On simulation  941  of  1000
#
# On simulation  942  of  1000
#
# On simulation  943  of  1000
#
# On simulation  944  of  1000
#
# On simulation  945  of  1000
#
# On simulation  946  of  1000
#
# On simulation  947  of  1000
#
# On simulation  948  of  1000
#
# On simulation  949  of  1000
#
# On simulation  950  of  1000
#
# On simulation  951  of  1000
#
# On simulation  952  of  1000
#
# On simulation  953  of  1000
#
# On simulation  954  of  1000
#
# On simulation  955  of  1000
#
# On simulation  956  of  1000
#
# On simulation  957  of  1000
#
# On simulation  958  of  1000
#
# On simulation  959  of  1000
#
# On simulation  960  of  1000
#
# On simulation  961  of  1000
#
# On simulation  962  of  1000
#
# On simulation  963  of  1000
#
# On simulation  964  of  1000
#
# On simulation  965  of  1000
#
# On simulation  966  of  1000
#
# On simulation  967  of  1000
#
# On simulation  968  of  1000
#
# On simulation  969  of  1000
#
# On simulation  970  of  1000
#
# On simulation  971  of  1000
#
# On simulation  972  of  1000
#
# On simulation  973  of  1000
#
# On simulation  974  of  1000
#
# On simulation  975  of  1000
#
# On simulation  976  of  1000
#
# On simulation  977  of  1000
#
# On simulation  978  of  1000
#
# On simulation  979  of  1000
#
# On simulation  980  of  1000
#
# On simulation  981  of  1000
#
# On simulation  982  of  1000
#
# On simulation  983  of  1000
#
# On simulation  984  of  1000
#
# On simulation  985  of  1000
#
# On simulation  986  of  1000
#
# On simulation  987  of  1000
#
# On simulation  988  of  1000
#
# On simulation  989  of  1000
#
# On simulation  990  of  1000
#
# On simulation  991  of  1000
#
# On simulation  992  of  1000
#
# On simulation  993  of  1000
#
# On simulation  994  of  1000
#
# On simulation  995  of  1000
#
# On simulation  996  of  1000
#
# On simulation  997  of  1000
#
# On simulation  998  of  1000
#
# On simulation  999  of  1000
#
# On simulation  1000  of  1000

# %%
df1 = pd.DataFrame()
df1['param'] = params
df1['dist'] = dists
df1.to_csv('/Users/maria/Desktop/Schelling_ML/ABC_reject_1000sims_51_norm.csv', index=False)

# %%
df2 = df1.sort_values(by='dist')

# %%
df_top50 = pd.DataFrame({'param': df2.iloc[:50]['param'], "label": "top 50"})
df_top100 = pd.DataFrame({'param': df2.iloc[:100]['param'], "label": "top 100"})
df_top250 = pd.DataFrame({'param': df2.iloc[:250]['param'], "label": "top 250"})
df_top500 = pd.DataFrame({'param': df2.iloc[:500]['param'], "label": "top 500"})
df_top750 = pd.DataFrame({'param': df2.iloc[:750]['param'], "label": "top 750"})
df_top1000 = pd.DataFrame({'param': df2.iloc[:1000]['param'], "label": "top 1000"})

# %%
df_formatted = pd.concat([df_top50, df_top100, df_top250, df_top500, df_top750, df_top1000], axis=0, ignore_index=True)

# %%
df_formatted
# Out:
#          param     label
# 0     0.566716    top 50
# 1     0.525929    top 50
# 2     0.557697    top 50
# 3     0.583641    top 50
# 4     0.540348    top 50
# ...        ...       ...
# 2645  0.912778  top 1000
# 2646  0.947822  top 1000
# 2647  0.912835  top 1000
# 2648  0.969111  top 1000
# 2649  0.913549  top 1000
#
# [2650 rows x 2 columns]

# %%
sns.displot(data=df_formatted, x='param', hue='label', kind='kde', fill=False, palette=sns.color_palette('bright')[:6], height=5, aspect=1.5)
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %%
sns.displot(data=df_top50, x='param', kind='kde', fill=False)
